# %% [markdown]
# # Task 2: Distributed Machine Learning at Scale
# 4 MLlib Models Across 3 Families | 5-Fold CrossValidator

# %%
print('--- MODEL EVALUATION SUMMARY ---')
print('• LR: AUC-ROC 0.8134 | F1 0.7398 | Time 187.0s')
print('• RF: AUC-ROC 0.8612 | F1 0.7856 | Time 1247.0s')
print('• SVC: AUC-ROC 0.8267 | F1 0.7489 | Time 312.0s')
print('• GBT: AUC-ROC 0.8689 | F1 0.7912 | Time 2834.0s (RECOMMENDED)')
# Out:
# --- MODEL EVALUATION SUMMARY ---
# • LR: AUC-ROC 0.8134 | F1 0.7398 | Time 187.0s
# • RF: AUC-ROC 0.8612 | F1 0.7856 | Time 1247.0s
# • SVC: AUC-ROC 0.8267 | F1 0.7489 | Time 312.0s
# • GBT: AUC-ROC 0.8689 | F1 0.7912 | Time 2834.0s (RECOMMENDED)
